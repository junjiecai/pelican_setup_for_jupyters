# %% [markdown]
# # About me
# I am a Data science engineer living in Shanghai and a life learner. Contact me by [Email](mailto:fredness7@hotmail.com)
#
#
# # About the site
# Articles in this site is generated from Jupyter's .ipynb by pelican and then published on gitpages. If you are interested in blogging in Jupyter. Welcome to fork [my project](https://github.com/junjiecai/pelican_setup_for_jupyters) and it help you build your blogs with Jupyter.
